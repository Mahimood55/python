# %%
import pandas as pd

# %%
emp=pd.read_excel(r"C:\Users\Shaik Mahimood\OneDrive\Documents\Downloads\excel 2.xlsx")

# %%
emp
# Out:
#    NAME GENDER  SFT OFFICE SHOPING  SCHOOLS METROS PLAYGROUP SALARY HOME   \
# 0   XYZ      M  100    NaN      NaN     NaN    NaN       NaN    NaN     Z
# 1   BZC      F  200     IY        N       N    NaN         Y      N     Y
# 2  ASDF      M  300    NaN        Y       Y      Y       NaN    200   NaN
#
#   SKIN HAIR  HEIGHT  WEIGHT PRICE Purchase
# 0    W    B     NaN     NaN  100M         Y
# 1  NaN  NaN     NaN    56.0  200M         N
# 2  NaN  NaN     6.0    70.0   300         y

# %%
emp.shape
# Out:
# (3, 16)

# %%
emp.columns
# Out:
# Index(['NAME', 'GENDER', 'SFT', 'OFFICE', 'SHOPING ', 'SCHOOLS', 'METROS',
#        'PLAYGROUP', 'SALARY', 'HOME ', 'SKIN', 'HAIR', 'HEIGHT', 'WEIGHT',
#        'PRICE', 'Purchase '],
#       dtype='object')

# %%
emp.isnull()
# Out:
#     NAME  GENDER    SFT  OFFICE  SHOPING   SCHOOLS  METROS  PLAYGROUP  SALARY  \
# 0  False   False  False    True      True     True    True       True    True
# 1  False   False  False   False     False    False    True      False   False
# 2  False   False  False    True     False    False   False       True   False
#
#    HOME    SKIN   HAIR  HEIGHT  WEIGHT  PRICE  Purchase
# 0  False  False  False    True    True  False      False
# 1  False   True   True    True   False  False      False
# 2   True   True   True   False   False  False      False

# %%
emp.isnull().sum()
# Out:
# NAME         0
# GENDER       0
# SFT          0
# OFFICE       2
# SHOPING      1
# SCHOOLS      1
# METROS       2
# PLAYGROUP    2
# SALARY       1
# HOME         1
# SKIN         2
# HAIR         2
# HEIGHT       2
# WEIGHT       1
# PRICE        0
# Purchase     0
# dtype: int64

# %%
emp['OFFICE']
# Out:
# 0    NaN
# 1     IY
# 2    NaN
# Name: OFFICE, dtype: object

# %%
emp['SCHOOLS']
# Out:
# 0    NaN
# 1      N
# 2      Y
# Name: SCHOOLS, dtype: object

# %%
clean_data=emp.copy()

# %%
clean_data
# Out:
#    NAME GENDER  SFT OFFICE SHOPING  SCHOOLS METROS PLAYGROUP SALARY HOME   \
# 0   XYZ      M  100    NaN      NaN     NaN    NaN       NaN    NaN     Z
# 1   BZC      F  200     IY        N       N    NaN         Y      N     Y
# 2  ASDF      M  300    NaN        Y       Y      Y       NaN    200   NaN
#
#   SKIN HAIR  HEIGHT  WEIGHT PRICE Purchase
# 0    W    B     NaN     NaN  100M         Y
# 1  NaN  NaN     NaN    56.0  200M         N
# 2  NaN  NaN     6.0    70.0   300         y

# %%
import numpy as np

# %%
clean_data['OFFICE']=clean_data['OFFICE'].fillna(clean_data['OFFICE'].mode()[0])

# %%
clean_data['OFFICE']
# Out:
# 0    IY
# 1    IY
# 2    IY
# Name: OFFICE, dtype: object

# %%
clean_data['SCHOOLS']=clean_data['SCHOOLS'].fillna(clean_data['SCHOOLS'].mode()[0])

# %%
clean_data['SCHOOLS']
# Out:
# 0    N
# 1    N
# 2    Y
# Name: SCHOOLS, dtype: object

# %%
clean_data['PLAYGROUP']=clean_data['PLAYGROUP'].fillna(clean_data['PLAYGROUP'].mode()[0])

# %%
clean_data['PLAYGROUP']
# Out:
# 0    Y
# 1    Y
# 2    Y
# Name: PLAYGROUP, dtype: object

# %%
clean_data['OFFICE']=clean_data['OFFICE'].fillna(clean_data['OFFICE'].mode()[0])

# %%
clean_data['OFFICE']
# Out:
# 0    IY
# 1    IY
# 2    IY
# Name: OFFICE, dtype: object

# %%
clean_data['SCHOOLS']=clean_data['SCHOOLS'].fillna(clean_data['SCHOOLS'].mode()[0])

# %%
clean_data['SCHOOLS']
# Out:
# 0    N
# 1    N
# 2    Y
# Name: SCHOOLS, dtype: object

# %%
clean_data['SHOPING']=clean_data['SHOPING'].fillna(clean_data['SHOPING'].mode()[0])

# %%
clean_data['SHOPING']
# Out:
# 0    N
# 1    N
# 2    Y
# Name: SHOPING, dtype: object

# %%
clean_data.columns = clean_data.columns.str.strip()

# %%
clean_data.columns
# Out:
# Index(['NAME', 'GENDER', 'SFT', 'OFFICE', 'SHOPING', 'SCHOOLS', 'METROS',
#        'PLAYGROUP', 'SALARY', 'HOME', 'SKIN', 'HAIR', 'HEIGHT', 'WEIGHT',
#        'PRICE', 'Purchase'],
#       dtype='object')

# %%
clean_data['SFT']=clean_data['SFT'].fillna(clean_data['SFT'].mode()[0])

# %%
clean_data['SFT']
# Out:
# 0    100
# 1    200
# 2    300
# Name: SFT, dtype: int64

# %%
clean_data['HOME']=clean_data['HOME'].fillna(clean_data['HOME'].mode()[0])

# %%
clean_data['HOME']
# Out:
# 0    Z
# 1    Y
# 2    Y
# Name: HOME, dtype: object

# %%
clean_data['SKIN']=clean_data['SKIN'].fillna(clean_data['SKIN'].mode()[0])

# %%
clean_data['SKIN']
# Out:
# 0    W
# 1    W
# 2    W
# Name: SKIN, dtype: object

# %%
clean_data['WEIGHT']=clean_data['WEIGHT'].fillna(clean_data['WEIGHT'].mode()[0])

# %%
clean_data['WEIGHT']
# Out:
# 0    56.0
# 1    56.0
# 2    70.0
# Name: WEIGHT, dtype: float64

# %%
clean_data['HEIGHT']=clean_data['HEIGHT'].fillna(clean_data['HEIGHT'].mode()[0])

# %%
clean_data['HEIGHT']
# Out:
# 0    6.0
# 1    6.0
# 2    6.0
# Name: HEIGHT, dtype: float64

# %%
clean_data
# Out:
#    NAME GENDER  SFT OFFICE SHOPING SCHOOLS METROS PLAYGROUP SALARY HOME SKIN  \
# 0   XYZ      M  100     IY       N       N    NaN         Y    NaN    Z    W
# 1   BZC      F  200     IY       N       N    NaN         Y      N    Y    W
# 2  ASDF      M  300     IY       Y       Y      Y         Y    200    Y    W
#
#   HAIR  HEIGHT  WEIGHT PRICE Purchase
# 0    B     6.0    56.0  100M        Y
# 1  NaN     6.0    56.0  200M        N
# 2  NaN     6.0    70.0   300        y

# %%
clean_data['SALARY']=clean_data['SALARY'].fillna(clean_data['SALARY'].mode()[0])
# Out:
# C:\Users\Shaik Mahimood\AppData\Local\Temp\ipykernel_14372\2270182905.py:1: UserWarning: Unable to sort modes: '<' not supported between instances of 'int' and 'str'
#   clean_data['SALARY']=clean_data['SALARY'].fillna(clean_data['SALARY'].mode()[0])

# %%
clean_data['SALARY']
# Out:
# 0      N
# 1      N
# 2    200
# Name: SALARY, dtype: object

# %%
clean_data['HAIR']=clean_data['HAIR'].fillna(clean_data['HAIR'].mode()[0])

# %%
clean_data['HAIR']
# Out:
# 0    B
# 1    B
# 2    B
# Name: HAIR, dtype: object

# %%
clean_data['METROS']=clean_data['METROS'].fillna(clean_data['METROS'].mode()[0])

# %%
clean_data['METROS']
# Out:
# 0    Y
# 1    Y
# 2    Y
# Name: METROS, dtype: object

# %%
clean_data['Purchase']=clean_data['Purchase'].fillna(clean_data['Purchase'].mode()[0])

# %%
clean_data['Purchase']
# Out:
# 0    Y
# 1    N
# 2    y
# Name: Purchase, dtype: object

# %%
clean_data['WEIGHT']=clean_data['WEIGHT'].fillna(np.mean(pd.to_numeric(clean_data['WEIGHT'])))

# %%
clean_data['WEIGHT']
# Out:
# 0    56.0
# 1    56.0
# 2    70.0
# Name: WEIGHT, dtype: float64

# %%
clean_data
# Out:
#    NAME GENDER  SFT OFFICE SHOPING SCHOOLS METROS PLAYGROUP SALARY HOME SKIN  \
# 0   XYZ      M  100     IY       N       N      Y         Y      N    Z    W
# 1   BZC      F  200     IY       N       N      Y         Y      N    Y    W
# 2  ASDF      M  300     IY       Y       Y      Y         Y    200    Y    W
#
#   HAIR  HEIGHT  WEIGHT PRICE Purchase
# 0    B     6.0    56.0  100M        Y
# 1    B     6.0    56.0  200M        N
# 2    B     6.0    70.0   300        y

# %%
clean_data.isnull()
# Out:
#     NAME  GENDER    SFT  OFFICE  SHOPING  SCHOOLS  METROS  PLAYGROUP  SALARY  \
# 0  False   False  False   False    False    False   False      False   False
# 1  False   False  False   False    False    False   False      False   False
# 2  False   False  False   False    False    False   False      False   False
#
#     HOME   SKIN   HAIR  HEIGHT  WEIGHT  PRICE  Purchase
# 0  False  False  False   False   False  False     False
# 1  False  False  False   False   False  False     False
# 2  False  False  False   False   False  False     False

# %%
clean_data.isnull().sum()
# Out:
# NAME         0
# GENDER       0
# SFT          0
# OFFICE       0
# SHOPING      0
# SCHOOLS      0
# METROS       0
# PLAYGROUP    0
# SALARY       0
# HOME         0
# SKIN         0
# HAIR         0
# HEIGHT       0
# WEIGHT       0
# PRICE        0
# Purchase     0
# dtype: int64

# %%
X_iv=clean_data[['NAME', 'GENDER', 'SFT', 'OFFICE', 'SHOPING', 'SCHOOLS', 'METROS',
       'PLAYGROUP', 'SALARY', 'HOME', 'SKIN', 'HAIR', 'HEIGHT', 'WEIGHT',
       'PRICE']]

# %%
X_iv
# Out:
#    NAME GENDER  SFT OFFICE SHOPING SCHOOLS METROS PLAYGROUP SALARY HOME SKIN  \
# 0   XYZ      M  100     IY       N       N      Y         Y      N    Z    W
# 1   BZC      F  200     IY       N       N      Y         Y      N    Y    W
# 2  ASDF      M  300     IY       Y       Y      Y         Y    200    Y    W
#
#   HAIR  HEIGHT  WEIGHT PRICE
# 0    B     6.0    56.0  100M
# 1    B     6.0    56.0  200M
# 2    B     6.0    70.0   300

# %%
y_dv=clean_data[['Purchase']]

# %%
y_dv
# Out:
#   Purchase
# 0        Y
# 1        N
# 2        y

# %%
imputation=pd.get_dummies(clean_data)

# %%
imputation
# Out:
#    SFT  HEIGHT  WEIGHT  NAME_ASDF  NAME_BZC  NAME_XYZ  GENDER_F  GENDER_M  \
# 0  100     6.0    56.0      False     False      True     False      True
# 1  200     6.0    56.0      False      True     False      True     False
# 2  300     6.0    70.0       True     False     False     False      True
#
#    OFFICE_IY  SHOPING_N  ...  HOME_Y  HOME_Z  SKIN_W  HAIR_B  PRICE_300  \
# 0       True       True  ...   False    True    True    True      False
# 1       True       True  ...    True   False    True    True      False
# 2       True      False  ...    True   False    True    True       True
#
#    PRICE_100M  PRICE_200M  Purchase_N  Purchase_Y  Purchase_y
# 0        True       False       False        True       False
# 1       False        True        True       False       False
# 2       False       False       False       False        True
#
# [3 rows x 27 columns]

# %%
clean_data
# Out:
#    NAME GENDER  SFT OFFICE SHOPING SCHOOLS METROS PLAYGROUP SALARY HOME SKIN  \
# 0   XYZ      M  100     IY       N       N      Y         Y      N    Z    W
# 1   BZC      F  200     IY       N       N      Y         Y      N    Y    W
# 2  ASDF      M  300     IY       Y       Y      Y         Y    200    Y    W
#
#   HAIR  HEIGHT  WEIGHT PRICE Purchase
# 0    B     6.0    56.0  100M        Y
# 1    B     6.0    56.0  200M        N
# 2    B     6.0    70.0   300        y
