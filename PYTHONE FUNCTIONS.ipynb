# %%
def greet():
    print('hello')
    print('good morning')
greet()
# Out:
# hello
# good morning

# %%
def name():
    print('mahimood')
    print('hussain')
name()
# Out:
# mahimood
# hussain

# %% [markdown]
# #PRINT MULTIPLE TIMES

# %%
def greet():
    print('data scince')
    print('course')
greet()

greet()

greet()

greet()
# Out:
# data scince
# course
# data scince
# course
# data scince
# course
# data scince
# course

# %%
def books():
    print('maths')
    print('computers')
    print('english')
books()
books()
# Out:
# maths
# computers
# english
# maths
# computers
# english

# %% [markdown]
# # python code add 2 numbers

# %%
def add(x,y):
    c=x+y
    print(c)
add(10,8)
# Out:
# 18

# %%
def sub(x,y):
    c=x-y
    print(c)
sub(25,12)
# Out:
# 13

# %%
def mul(x,y):
    c=x*y
    print(c)
mul(10,9)
# Out:
# 90

# %%
def div(x,y):
    c=x/y
    print(c)
div(80,5)
# Out:
# 16.0

# %% [markdown]
# # write a python code add 3 number

# %%
def add(x,y,z):
    c=x+y+z
    print(c)
add(8,19,34)
# Out:
# 61

# %%
def add(x,y,z):       # use any operations + - / *
    c=x+y+z
    print(c)
add(18,19,34)
# Out:
# -35

# %%
def sub(x,y,z):
    c=x-y-z
    print(c)
sub(8,19,34)
# Out:
# -45

# %%
def mul(x,y,z):
    c=x*y*z
    print(c)
mul(8,19,34)
# Out:
# 5168

# %%
def greet():
    print('hey')
    print('google')

greet()
# Out:
# hey
# google

# %% [markdown]
# # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value

# %%
def greet():
    print('hey')
    print('google')
def add(x,y,z):
    c=x+y+z
    return c
greet()

result=add(5,6,9)
print(result)
# Out:
# hey
# google
# 20

# %%
def add_sub(x,y):
    a=x+y
    b=x-y
    c=x*y
    d=x/y
    e=x**y
    print(a,b,c,d,e)
add_sub(15,8)
# Out:
# 23 7 120 1.875 2562890625

# %%
def add_sub(x,y):
    a=x+y
    b=x-y
    c=x*y
    d=x/y
    print(a,b,c,d)
add_sub(1,8)
# Out:
# 9 -7 8 0.125

# %%
def add_sub(x,y):
    a=x+y
    b=x-y
    print(a,b)
add_sub(9,15)
# Out:
# 24 -6

# %%
def add_sub(x,y):
    c= x+y
    d= x-y
    return c, d
    
result = add_sub(14,25)

print(result)
print(type(result))
# Out:
# (39, -11)
# <class 'tuple'>

# %%
def add_sub(x,y):
    c= x+y
    d= x-y
    return c, d
    
result,result1 = add_sub(14,25)

print(result,result1)
print(type(result))
print(type(result1))
# Out:
# 39 -11
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # update function take the value from the user

# %%
def car(l):
    l=25
    print(l)
car(35)
# Out:
# 25

# %%
def car(l):
    l=25
    print(l)

m=35
car(m)
print(m)
# Out:
# 25
# 35

# %% [markdown]
# # formal argument

# %%
class nit:
    def add(self, a, b):   # formal argument
        c = a + b
        print(c)

obj = nit() 
obj.add(5, 6) #actual argument
# Out:
# 11

# %%
class nit:
    def add(self, a, b):  # Added 'self'
        c = a + b
        print(c)

obj = nit()  # Create an instance
obj.add(15, 36)
# Out:
# 51

# %%
def update():
    x=8             #without arguments
    print(x)
update()
# Out:
# 8

# %%
def update(x):
    x=8              # with argument
    print(x)
update(8)
# Out:
# 8

# %%
def update(x):
    x=40              # with argument
    print(x)
update(67)
# Out:
# 40

# %%
def bike(m):
    m=15
    print(m)

k=25
update(k)
print(k)
# Out:
# 40
# 25

# %% [markdown]
# # actual argument
#     - positional argument
#     - keyword argument
#     - variable lenght
#     - defaul

# %% [markdown]
# # positional argument

# %%
def person(name,age):
    print(name)
    print(age)
person('mahimood',15)
# Out:
# mahimood
# 15

# %%
def person(name,age):
    print(name)            # we have not defined proper positions we have got output
    print(age)
person(15,'mahimood')
# Out:
# 15
# mahimood

# %%
def person(name,age,gender):
    print(name)
    print(age)
    print(gender)
person('mahimood',15,'male')
# Out:
# mahimood
# 15
# male

# %%
def person(name,age):     #but we have add or sub values if there are proper posision give
    print(name)
    print(age-4)
person(15,'mahimood')
# Out:
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 4
#       2     print(name)
#       3     print(age-4)
# ----> 4 person(15,'mahimood')
#
# Cell In[68], line 3, in person(name, age)
#       1 def person(name,age):
#       2     print(name)
# ----> 3     print(age-4)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
def person(name,age):     #but we have add or sub values if there are proper posision give
    print(name)
    print(age-4)
person('mahimood',20)
# Out:
# mahimood
# 16

# %%
def person(name,age):#but we have give 2 arguments but more then 2 is give there are error
    print(name)
    print(age)
person('mahimood',20,'ball')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       2     print(name)         #but we have give 2 arguments but more then 2 is give there are error
#       3     print(age)
# ----> 5 person(22, 'nit', 5)
#
# TypeError: person() takes 2 positional arguments but 3 were given

# %% [markdown]
# # keyword argument

# %%
def person(name,age):
    print(name)
    print(age)

person(age=34,name='mahimood')
# Out:
# mahimood
# 34

# %%
def person(name,age):
    print(name)
    print(age)

person(age=34,name2='mahimood')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person(age=34,name2='mahimood')
#
# TypeError: person() got an unexpected keyword argument 'name2'

# %%
def person(name,age):
    print(name)
    print(age-10)

person(age=34,name='mahimood')
# Out:
# mahimood
# 24

# %%
def person(name):
    print(name)
    print(age)

person(age=34,name='mahimood')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person(age=34,name='mahimood')
#
# TypeError: person() got an unexpected keyword argument 'age'

# %% [markdown]
# # DEFAULT ARGUMENT

# %%
def person(name,age=21):
    print(name)   #if we are not give age but system give defualt 21 
    print(age)
person('mahimood')
# Out:
# mahimood
# 21

# %%
def person(name,age=21):
    print(name)   #if we are not give age but system give defualt 21 
    print(age)
person('mahimood',45)
# Out:
# mahimood
# 45

# %%
def person(name,age=25):
    print(name)   #if we are not give age but system give defualt 21 
    print(age)
person('mahimood')
# Out:
# mahimood
# 25

# %% [markdown]
# # variable length argument

# %%
def sum(x,y):
    c=x+y
    print(c)
sum(34,23)
# Out:
# 57

# %%
def sum(a,*b):
    c=a
    for i in b:
        c=c+i
    print(c)

sum(4,3,5,6,8)
# Out:
# 26

# %%
def add(a,*b):
    c=a                 #add last variable in *
    for i in b:
        c=c+i
    print(c)

sum(12,34,2,3,4,55,67)
# Out:
# 177

# %%
def sum(a,*b):
    c=0
    for i in b:      # c value is o then first value is 0
        c=c+i
    print(c)

sum(4,3,5,6,8)
# Out:
# 22

# %%
def sum(a,*b):
    c=9
    for i in b:
        c=c+i
    print(c)

sum(4,3,5,6,8)
# Out:
# 31

# %%
def sum(a,*b):
    c=12
    for i in b:
        c=c+i
    print(c)

sum(4,3,5,6,8)
# Out:
# 34

# %% [markdown]
# # keyworded variable length argument

# %%
def parsons(name,*data):
    print(name)
    print(data)
parsons('mahimood',15,'hussain',25)
# Out:
# mahimood
# (15, 'hussain', 25)

# %%
def parsons(name,*data):
    print(name)
    print(data)
parsons('mahimood',34,'hussain',56)
# Out:
# mahimood
# (34, 'hussain', 56)

# %%
def person(name,*data):
    print('name')        #we have using only one * there is error
    print(data)

person('mahimood',age=22,place='mkp',mobil=950243)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 5
#       2     print('name')
#       3     print(data)
# ----> 5 person('mahimood',age=22,place='mkp',mobil=950243)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name,**data):
    print('name')      
    print(data)

person('mahimood',age=22,place='mkp',mobil=950243)
# Out:
# name
# {'age': 22, 'place': 'mkp', 'mobil': 950243}

# %%
def person(details,**data):
    print(details)      
    print(data)

person('mahimood',age=22,place='mkp',mobil=950243)
# Out:
# mahimood
# {'age': 22, 'place': 'mkp', 'mobil': 950243}

# %%
def person(details,**data):
    print('details')         # its printed for dict
    print(data)

person('mahimood',age=22,place='mkp',mobil=950243)
# Out:
# details
# {'age': 22, 'place': 'mkp', 'mobil': 950243}
