# %%
import numpy

# %% [raw]
# import numpy as np

# %%
Years=["2002","2003","2004","2005"]

# %%
Sdict={"2002":0,"2003":1,"2004":2,"2005":3}

# %%
Items=["chocolate","Puffs","Cooldrinks","chips"]

# %%
Pdict={"chocolate":0,"Puffs":1,"Cooldrinks":3,"chips":4}

# %%
#sale

# %%
import numpy as np

# %%
Chocolate_sale=[20000,40000,60000,80000]

# %%
Puffs_sale=[30000,40000,20000,10000]

# %%
Cooldriks_sale=[40000,50000,60000,70000]

# %%
chips_sale=[20000,30000,50000,90000]

# %%
sale=np.array([Chocolate_sale,Puffs_sale,Cooldriks_sale,chips_sale])

# %%
sale
# Out:
# array([[20000, 40000, 60000, 80000],
#        [30000, 40000, 20000, 10000],
#        [40000, 50000, 60000, 70000],
#        [20000, 30000, 50000, 90000]])

# %%
Pdict
# Out:
# {'chocolate': 0, 'Puffs': 1, 'Cooldrinks': 3, 'chips': 4}

# %%
Pdict['chocolate']
# Out:
# 0

# %%
sale[0]
# Out:
# array([20000, 40000, 60000, 80000])

# %%
Pdict['Puffs']
# Out:
# 1

# %%
sale[1]
# Out:
# array([30000, 40000, 20000, 10000])

# %%
Pdict['Cooldrinks']
# Out:
# 3

# %%
sale[3]
# Out:
# array([20000, 30000, 50000, 90000])

# %%
Pdict['chips']
# Out:
# 4

# %%
sale[2]
# Out:
# array([40000, 50000, 60000, 70000])

# %%
import matplotlib.pyplot as plt

# %% [raw]
# %matplotlib inline

# %%
sale
# Out:
# array([[20000, 40000, 60000, 80000],
#        [30000, 40000, 20000, 10000],
#        [40000, 50000, 60000, 70000],
#        [20000, 30000, 50000, 90000]])

# %%
plt.plot(Puffs_sale)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns

# %%
sns.boxplot(Puffs_sale)
# Out:
# <Axes: >

# %%
sns.barplot(Puffs_sale)
# Out:
# <Axes: >

# %%
sns.catplot(Puffs_sale)

# %%
sns.catplot(Puffs_sale),True
# Out:
# (<seaborn.axisgrid.FacetGrid at 0x1c0cfbd7890>, True)

# %%
sns.violinplot(Puffs_sale)
# Out:
# <Axes: >
