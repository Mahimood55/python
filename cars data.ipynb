# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars=pd.read_excel(r"C:\Users\Shaik Mahimood\Downloads\14th- Stats introduction , exam answer\14th- Stats introduction , exam answer\stats - 1\2.Fundamental of descriptive stats\1.Categorical-variables.Visualization-techniques-lesson.xlsx")

# %%
cars
# Out:
#    Unnamed: 0 Graphs and tables for categorical variables Unnamed: 2
# 0         NaN                             German car shop        NaN
# 1         NaN                                         NaN        NaN
# 2         NaN                                         NaN  Frequency
# 3         NaN                                        Audi        124
# 4         NaN                                         BMW         98
# 5         NaN                                    Mercedes        113
# 6         NaN                                       Total        335

# %%
cars.isnull()
# Out:
#    Unnamed: 0  Graphs and tables for categorical variables  Unnamed: 2
# 0        True                                        False        True
# 1        True                                         True        True
# 2        True                                         True       False
# 3        True                                        False       False
# 4        True                                        False       False
# 5        True                                        False       False
# 6        True                                        False       False

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   0 non-null      float64
#  1   Graphs and tables for categorical variables  5 non-null      object
#  2   Unnamed: 2                                   5 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 300.0+ bytes

# %%
cars.isnull().sum()
# Out:
# Unnamed: 0                                     7
# Graphs and tables for categorical variables    2
# Unnamed: 2                                     2
# dtype: int64

# %%
car={'Audi':124,'BMW':98,'Mercedes':113}

# %%
car
# Out:
# {'Audi': 124, 'BMW': 98, 'Mercedes': 113}

# %%
cars.categorical={'Audi','BMW','Mercedes'}
# Out:
# C:\Users\Shaik Mahimood\AppData\Local\Temp\ipykernel_16256\4062260479.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   cars.categorical={'Audi','BMW','Mercedes'}

# %%
cars.categorical
# Out:
# {'Audi', 'BMW', 'Mercedes'}

# %%
cars.numarical=[124,98,113]
# Out:
# C:\Users\Shaik Mahimood\AppData\Local\Temp\ipykernel_16256\2193441413.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   cars.numarical=[124,98,113]

# %%
cars.numarical
# Out:
# [124, 98, 113]

# %%
sns.barplot(car,color='Green')
plt.xlabel('category')
plt.ylabel('numerical')
plt.title("Luxory Cars Data")
plt.show()

# %%
car= {
'category': ['Audi', 'BMW', 'Mercedes'],
'numeric': [124, 98, 113]
}
Luxurycars = pd.DataFrame(car)
plt.figure(figsize=(5,5))
plt.pie(Luxurycars['numeric'], labels=Luxurycars['category'],
autopct='%1.1f%%')
plt.title("germans Cars Data")
plt.axis('equal')
plt.show()
