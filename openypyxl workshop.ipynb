# %%
import openpyxl

# %% [raw]
# import pandas as pd

# %%
workbook=openpyxl.Workbook()

# %%
sheet=workbook.active

# %%
data=[
    ['NAMES','DOMAIN','AGE','LOCATION','SALARY','EXP'],
    ['MAHIMOOD','DTSCIENCE',24,'MKP',100000,10],
    ['DURGA','CAPTAIN',24,'TPRM',100000,9],
    ['NASREEN','BNSALE',26,'HYD',200000,15],
    ['RESHMA','MBA',28,'GNP',80000,10],
    ['JAVEED','BANK',30,'GNP',80000,10]
]
for row in data:
    sheet.append(row)
workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAMES', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
#  ['MAHIMOOD', 'DTSCIENCE', 24, 'MKP', 100000, 10],
#  ['DURGA', 'CAPTAIN', 24, 'TPRM', 100000, 9],
#  ['NASREEN', 'BNSALE', 26, 'HYD', 200000, 15],
#  ['RESHMA', 'MBA', 28, 'GNP', 80000, 10],
#  ['JAVEED', 'BANK', 30, 'GNP', 80000, 10]]

# %%
import pandas as pd

# %% [raw]
# import os
# os.getcmd()

# %%
emp=pd.read_excel(r'C:\\Users\\Shaik Mahimood\data.xlsx')
emp
# Out:
#       NAMES     DOMAIN  AGE LOCATION  SALARY  EXP
# 0  MAHIMOOD  DTSCIENCE   24      MKP  100000   10
# 1     DURGA    CAPTAIN   24     TPRM  100000    9
# 2   NASREEN     BNSALE   26      HYD  200000   15
# 3    RESHMA        MBA   28      GNP   80000   10
# 4    JAVEED       BANK   30      GNP   80000   10

# %%
emp.shape
# Out:
# (5, 6)

# %%
emp.columns
# Out:
# Index(['NAMES', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp)
# Out:
# 5

# %%
emp['SALARY']
# Out:
# 0    100000
# 1    100000
# 2    200000
# 3     80000
# 4     80000
# Name: SALARY, dtype: int64

# %%
emp[['SALARY','EXP']]
# Out:
#    SALARY  EXP
# 0  100000   10
# 1  100000    9
# 2  200000   15
# 3   80000   10
# 4   80000   10

# %%
emp[['NAMES','AGE']]
# Out:
#       NAMES  AGE
# 0  MAHIMOOD   24
# 1     DURGA   24
# 2   NASREEN   26
# 3    RESHMA   28
# 4    JAVEED   30

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
vis1=sns.displot(emp['SALARY'])

# %%
vis2=sns.distplot(emp['SALARY'])
# Out:
# C:\Users\Shaik Mahimood\AppData\Local\Temp\ipykernel_4212\375839575.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2=sns.distplot(emp['SALARY'])

# %%
vis3=plt.hist(emp['SALARY'])

# %%
vis4=plt.hist(emp['AGE'])

# %%
vis5=sns.distplot(emp['AGE'])
# Out:
# C:\Users\Shaik Mahimood\AppData\Local\Temp\ipykernel_4212\1827888671.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis5=sns.distplot(emp['AGE'])

# %%
plt.rcParams['figure.figsize']=1,1

# %%
vis6=sns.lmplot(data=emp,x='EXP',y='SALARY')

# %%
vis6=sns.lmplot(data=emp,x='EXP',y='SALARY',fit_reg=False)

# %%
vis6=sns.lmplot(data=emp,x='EXP',y='SALARY',fit_reg=True)

# %%
vis7=sns.lmplot(data=emp,x='AGE',y='EXP')

# %%
vis7=sns.lmplot(data=emp,x='AGE',y='EXP',fit_reg=True)

# %%
vis7=sns.lmplot(data=emp,x='AGE',y='EXP',fit_reg=False)
