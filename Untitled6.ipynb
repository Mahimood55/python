# %%
import numpy as np

# %%
ones_arr=np.ones((5,5),dtype=int)

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
elephent=Image.open(r'C:\Users\Shaik Mahimood\OneDrive\Documents\Downloads\ele.jpg')

# %%
elephent
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=199x148>

# %%
elephent
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=199x148>

# %%
type(elephent)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
elephent_arr=np.asarray(elephent)
elephent_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
type(elephent)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
plt.imshow(elephent)

# %%
elephent_arr.shape
# Out:
# (148, 199, 3)

# %%
elephent_red=elephent_arr.copy()

# %%
elephent_red
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
elephent_red.shape
# Out:
# (148, 199, 3)

# %%
plt.imshow(elephent_red[:,:,0])

# %%
plt.imshow(elephent_red[0:,0:,1])

# %%
plt.imshow(elephent_red[0:,0:,1],cmap='gray')

# %%
plt.imshow(elephent_red[0:,0:,1],cmap='Grays')

# %%
plt.imshow(elephent_red[0:,0:,1],cmap='Blues')

# %%
elephent_imge=elephent_arr.copy()

# %%
elephent_imge[:,:,0]=0

# %%
plt.imshow(elephent_imge)

# %%
elephent_imge[:,:,1]=0

# %%
plt.imshow(elephent_imge)
