# %%
import pandas as pd

# %%
emp=pd.read_excel(r"C:\Users\Shaik Mahimood\OneDrive\Documents\Downloads\book3.xlsx")

# %%
emp
# Out:
#   Name   age  gender school hospital      price
# 0   ab  35.0    male    yes      yes   200000.0
# 1   bc  28.0     NaN    NaN       no   300000.0
# 2   cd  42.0     NaN    NaN      yes        NaN
# 3   de   NaN  female    NaN      NaN   700000.0
# 4   ef   NaN     NaN     no      NaN  1200000.0

# %%
emp.columns
# Out:
# Index(['Name', 'age', 'gender', 'school', 'hospital', 'price'], dtype='object')

# %%
emp.shape
# Out:
# (5, 6)

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   age       3 non-null      float64
#  2   gender    2 non-null      object
#  3   school    2 non-null      object
#  4   hospital  3 non-null      object
#  5   price     4 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 372.0+ bytes

# %%
emp.isnull()
# Out:
#     Name    age  gender  school  hospital  price
# 0  False  False   False   False     False  False
# 1  False  False    True    True     False  False
# 2  False  False    True    True     False   True
# 3  False   True   False    True      True  False
# 4  False   True    True   False      True  False

# %%
emp.isnull().sum()
# Out:
# Name        0
# age         2
# gender      3
# school      3
# hospital    2
# price       1
# dtype: int64

# %%
emp['Name']
# Out:
# 0    ab
# 1    bc
# 2    cd
# 3    de
# 4    ef
# Name: Name, dtype: object

# %%
emp['age']
# Out:
# 0    35.0
# 1    28.0
# 2    42.0
# 3     NaN
# 4     NaN
# Name: age, dtype: float64

# %%
emp['gender']
# Out:
# 0      male
# 1       NaN
# 2       NaN
# 3    female
# 4       NaN
# Name: gender, dtype: object

# %%
emp['gender']=emp['gender'].str.replace(r'\W','')

# %%
emp['gender']
# Out:
# 0      male
# 1       NaN
# 2       NaN
# 3    female
# 4       NaN
# Name: gender, dtype: object

# %%
emp['school']
# Out:
# 0    yes
# 1    NaN
# 2    NaN
# 3    NaN
# 4     no
# Name: school, dtype: object

# %%
clean_data=emp.copy()

# %%
clean_data
# Out:
#   Name   age  gender school hospital      price
# 0   ab  35.0    male    yes      yes   200000.0
# 1   bc  28.0     NaN    NaN       no   300000.0
# 2   cd  42.0     NaN    NaN      yes        NaN
# 3   de   NaN  female    NaN      NaN   700000.0
# 4   ef   NaN     NaN     no      NaN  1200000.0

# %%
import numpy as np

# %%
clean_data['age']=clean_data['age'].fillna(np.mean(pd.to_numeric(clean_data['age'])))

# %%
clean_data['age']
# Out:
# 0    35.0
# 1    28.0
# 2    42.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
clean_data['school']
# Out:
# 0    yes
# 1    NaN
# 2    NaN
# 3    NaN
# 4     no
# Name: school, dtype: object

# %%
clean_data['hospital']=clean_data['hospital'].fillna(clean_data['hospital'].mode()[0])

# %%
clean_data['hospital']
# Out:
# 0    yes
# 1     no
# 2    yes
# 3    yes
# 4    yes
# Name: hospital, dtype: object

# %%
clean_data['gender']=clean_data['gender'].fillna(clean_data['gender'].mode()[0])

# %%
clean_data['gender']
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4    female
# Name: gender, dtype: object

# %%
clean_data['price']=clean_data['price'].fillna(np.mean(pd.to_numeric(clean_data['price'])))

# %%
clean_data['price']
# Out:
# 0     200000.0
# 1     300000.0
# 2     600000.0
# 3     700000.0
# 4    1200000.0
# Name: price, dtype: float64

# %%
clean_data['school']=clean_data['school'].fillna(clean_data['school'].mode()[0])

# %%
clean_data['school']
# Out:
# 0    yes
# 1     no
# 2     no
# 3     no
# 4     no
# Name: school, dtype: object

# %%
clean_data
# Out:
#   Name   age  gender school hospital      price
# 0   ab  35.0    male    yes      yes   200000.0
# 1   bc  28.0  female     no       no   300000.0
# 2   cd  42.0  female     no      yes   600000.0
# 3   de  35.0  female     no      yes   700000.0
# 4   ef  35.0  female     no      yes  1200000.0

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      object
#  1   age       5 non-null      float64
#  2   gender    5 non-null      object
#  3   school    5 non-null      object
#  4   hospital  5 non-null      object
#  5   price     5 non-null      float64
# dtypes: float64(2), object(4)
# memory usage: 372.0+ bytes

# %%
clean_data.columns
# Out:
# Index(['Name', 'age', 'gender', 'school', 'hospital', 'price'], dtype='object')

# %%
import matplotlib.pyplot as plt # visualization
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
clean_data['price']
# Out:
# 0     200000.0
# 1     300000.0
# 2     600000.0
# 3     700000.0
# 4    1200000.0
# Name: price, dtype: float64

# %%
vis1=sns.distplot(clean_data['price'])

# %%
vis2=plt.hist(clean_data['price'])

# %%
vis3=sns.lmplot(clean_data,x='age',y='price')

# %%
vis3=sns.lmplot(clean_data,x='age',y='price',fit_reg=False)

# %%
clean_data[:]
# Out:
#   Name   age  gender school hospital      price
# 0   ab  35.0    male    yes      yes   200000.0
# 1   bc  28.0  female     no       no   300000.0
# 2   cd  42.0  female     no      yes   600000.0
# 3   de  35.0  female     no      yes   700000.0
# 4   ef  35.0  female     no      yes  1200000.0

# %%
clean_data[0:5:2]
# Out:
#   Name   age  gender school hospital      price
# 0   ab  35.0    male    yes      yes   200000.0
# 2   cd  42.0  female     no      yes   600000.0
# 4   ef  35.0  female     no      yes  1200000.0

# %%
clean_data[::-1]
# Out:
#   Name   age  gender school hospital      price
# 4   ef  35.0  female     no      yes  1200000.0
# 3   de  35.0  female     no      yes   700000.0
# 2   cd  42.0  female     no      yes   600000.0
# 1   bc  28.0  female     no       no   300000.0
# 0   ab  35.0    male    yes      yes   200000.0

# %%
X_iv=clean_data[['Name','age','gender','school','hospital']]

# %%
X_iv
# Out:
#   Name   age  gender school hospital
# 0   ab  35.0    male    yes      yes
# 1   bc  28.0  female     no       no
# 2   cd  42.0  female     no      yes
# 3   de  35.0  female     no      yes
# 4   ef  35.0  female     no      yes

# %%
y_dv=clean_data[['price']]

# %%
y_dv
# Out:
#        price
# 0   200000.0
# 1   300000.0
# 2   600000.0
# 3   700000.0
# 4  1200000.0

# %%
imputation =pd.get_dummies(clean_data)

# %%
imputation
# Out:
#     age      price  Name_ab  Name_bc  Name_cd  Name_de  Name_ef  \
# 0  35.0   200000.0     True    False    False    False    False
# 1  28.0   300000.0    False     True    False    False    False
# 2  42.0   600000.0    False    False     True    False    False
# 3  35.0   700000.0    False    False    False     True    False
# 4  35.0  1200000.0    False    False    False    False     True
#
#    gender_female  gender_male  school_no  school_yes  hospital_no  \
# 0          False         True      False        True        False
# 1           True        False       True       False         True
# 2           True        False       True       False        False
# 3           True        False       True       False        False
# 4           True        False       True       False        False
#
#    hospital_yes
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True

# %%
clean_data
# Out:
#   Name   age  gender school hospital      price
# 0   ab  35.0    male    yes      yes   200000.0
# 1   bc  28.0  female     no       no   300000.0
# 2   cd  42.0  female     no      yes   600000.0
# 3   de  35.0  female     no      yes   700000.0
# 4   ef  35.0  female     no      yes  1200000.0

# %%
imputation
# Out:
#     age      price  Name_ab  Name_bc  Name_cd  Name_de  Name_ef  \
# 0  35.0   200000.0     True    False    False    False    False
# 1  28.0   300000.0    False     True    False    False    False
# 2  42.0   600000.0    False    False     True    False    False
# 3  35.0   700000.0    False    False    False     True    False
# 4  35.0  1200000.0    False    False    False    False     True
#
#    gender_female  gender_male  school_no  school_yes  hospital_no  \
# 0          False         True      False        True        False
# 1           True        False       True       False         True
# 2           True        False       True       False        False
# 3           True        False       True       False        False
# 4           True        False       True       False        False
#
#    hospital_yes
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
