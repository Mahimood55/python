# %%
import os

# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyADirafI7__w5DlzfTt5JoC0bz7W3wAi34")

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import PIL.Image

img1 = PIL.Image.open(r"C:\Users\Shaik Mahimood\Pictures\city.jpg")
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
prompt = "Describe the image"

# Generate content using the model
response = model.generate_content([prompt, img1])

# Print the generated text
print(response.text)
# Out:
# Here's a description of the image:
#
# The image is a picturesque evening scene of a canal-side row of historic buildings, likely in a Dutch city.
#
#
# Here's a breakdown of the elements:
#
# * **Architecture:** The buildings are classic Dutch architecture, with gabled roofs, brick facades, and multiple stories. They range in style slightly, showing a mix of ages, but maintain a cohesive, historical feel. Many windows are lit, creating a warm glow against the darkening sky.
#
# * **Waterfront:** A calm canal reflects the buildings and the sky, creating a near-perfect mirror image. Two boats are moored along the quay: a small, possibly pleasure craft, and a larger tugboat, which is prominent in the scene.
#
# * **Sky:** The sky is a dramatic mix of dark, brooding clouds and pockets of vibrant, golden-orange light from a likely sunset. This contrast adds a powerful sense of atmosphere to the scene.
#
# * **Lighting:** The warm light from the buildings' windows contrasts beautifully with the darker, more ominous sky. Streetlights add a touch of illumination along the waterfront.
#
# * **Overall Impression:** The image evokes a sense of peace and tranquility, but also of drama due to the contrast between the warm light of the town and the stormy clouds. The reflection on the water enhances the beauty and symmetry of the scene.  The photographer has skillfully captured a beautiful moment, showing the picturesque charm of this waterfront setting.
